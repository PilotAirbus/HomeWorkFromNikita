# %%
import pandas as pd

# %%
df = pd.read_csv('students_courses.csv')

# %%
print(df)
# Out:
#         Имя  Возраст        Курс  Оценка
# 0  Григорий       21  Математика      86
# 1    Кирилл       22      Физика      82
# 2   Татьяна       20  Математика      91
# 3      Олег       23       Химия      78
# 4      Вера       24      Физика      85

# %%
find_data = df[df['Оценка'] > 80]

# %%
print(find_data)
# Out:
#         Имя  Возраст        Курс  Оценка
# 0  Григорий       21  Математика      86
# 1    Кирилл       22      Физика      82
# 2   Татьяна       20  Математика      91
# 4      Вера       24      Физика      85

# %%
groups_data = df.groupby('Курс')['Оценка'].mean()
print(groups_data)
# Out:
# Курс
# Математика    88.5
# Физика        83.5
# Химия         78.0
# Name: Оценка, dtype: float64

# %%
groups_data.to_csv('semester_average_scores.csv')
